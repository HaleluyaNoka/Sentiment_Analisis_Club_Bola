# %%
import subprocess

# %%
# Tittle twitter auth token

twitter_auth_token = 'aa7602d8fcc19a264d60b69c30566f78b6db18f8'

# %%
filename = 'sentiment.csv'
search_keyword = 'manchester united lang:it'
limit = 1000

command = f'npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}'

try:
    subprocess.run(command, shell=True, check=True)
    print(f'Data successfully saved to {filename}')
except subprocess.CalledProcessError as e:
    print(f"An error occurred: {e}")
# Out:
# Data successfully saved to sentiment.csv
